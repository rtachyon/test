# %%
import pandas as pd

# Load the CSV file from the URL
url = 'https://gist.githubusercontent.com/mattkram/9684863843254402942dfede27af2cb7/raw/2590dd8185b833aacf247c0595edbb07a025a6d7/Smithsonian_VOTW_Holocene_Volcanoes.csv'
volcanoes_df = pd.read_csv(url)

# Display the first 10 rows
print("First 10 rows of the dataset:")
volcanoes_df.head(10)
# Out:
# First 10 rows of the dataset:
#                                                  FID  Volcano_Number  \
# 0  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210010
# 1  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210020
# 2  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210030
# 3  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210040
# 4  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211004
# 5  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211010
# 6  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211020
# 7  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211031
# 8  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211030
# 9  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211041
#
#                 Volcano_Name Primary_Volcano_Type  Last_Eruption_Year  \
# 0  West Eifel Volcanic Field       Volcanic field             -8300.0
# ...

# %%
url?
# Out:
# Type:        str
# String form: https://gist.githubusercontent.com/mattkram/9684863843254402942dfede27af2cb7/raw/2590dd8185b833aacf247c0595edbb07a025a6d7/Smithsonian_VOTW_Holocene_Volcanoes.csv
# Length:      161
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.

# %%
import math

# %% [markdown]
# # 이것은 표제이다.
# 이것은 단락이다
# - 조항 쓰기도
# - 이렇게 표현 할수 있다.
# 테이블도 기술 할수 있다.
#
# package|version
# -------|-------
# pandas|0.19.2
# matplotlib|2.0.0!

# %% [markdown]
# ## 수식 표시
# 이코드 셀에는 다음과 같이 서식을 표현할 수 있다.
# \begin{align}
# \sqrt{2x-1}+(3+x)^3
# \end{align}
#
# $$ E = mc ^ 2 $$

# %%
# %pwd
# Out:
# 'C:\\Users\\rtach'

# %%
working_dir = %pwd

# %%
working_dir
# Out:
# 'C:\\Users\\rtach'

# %%
# %time sum(range(100000000))
# Out:
# CPU times: total: 2.94 s
# Wall time: 2.92 s
# 4999999950000000

# %%
# %timeit -n 2000 -r 5 sum(range(10000))
# Out:
# 109 µs ± 1.63 µs per loop (mean ± std. dev. of 5 runs, 2,000 loops each)

# %%
# %history
# Out:
# import pandas as pd
#
# import json
# import getpass
# import hashlib
#
# def import_pandas_safely():
#     try:
#         return __import__('pandas')
#     except ImportError:
#         return False
#
#
# __pandas = import_pandas_safely()
#
#
# def is_data_frame(v: str):
#     obj = eval(v)
#     if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):
#         return True
#
#
# def dataframe_columns(var):
#     df = eval(var)
#     if isinstance(df, __pandas.core.series.Series):
#         return [[df.name, str(df.dtype)]]
#     return list(map(lambda col: [col, str(df[col].dtype)], df.columns))
#
#
# def dtypes_str(frame):
#     return str(eval(frame).dtypes)
#
# def dataframe_hash(var):
#     # Return a hash including the column names and number of rows
#     df = eval(var)
#     if isinstance(df, __pandas.core.series.Series):
#         return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode('utf-8')).hexdigest()
# ...

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: SSD1(OS)
#  볼륨 일련 번호: F6F9-D038
#
#  C:\Users\rtach 디렉터리
#
# 2025-06-22  오전 09:35    <DIR>          .
# 2025-06-22  오전 09:35    <DIR>          ..
# 2024-09-21  오후 11:40    <DIR>          .ammonite
# 2025-06-22  오전 08:29    <DIR>          .anaconda
# 2024-01-04  오전 11:56    <DIR>          .aws
# 2024-01-04  오전 11:56    <DIR>          .azure
# 2025-02-06  오전 12:28           226,770 .babel.json
# 2024-09-22  오후 04:31    <DIR>          .bloop
# 2024-09-21  오전 11:37    <DIR>          .bridge
# 2023-10-29  오전 10:32    <DIR>          .cache
# 2025-06-22  오전 09:53    <DIR>          .conda
# 2024-03-08  오전 12:01                25 .condarc
# 2024-09-22  오후 04:30    <DIR>          .config
# 2024-03-08  오전 12:01    <DIR>          .continuum
# 2025-02-18  오전 10:43    <DIR>          .docker
# 2024-09-22  오후 02:46             3,832 .dotty_history
# 2023-10-31  오후 01:26    <DIR>          .eclipse
# 2025-06-20  오후 11:24               178 .gitconfig
# ...

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: SSD1(OS)
#  볼륨 일련 번호: F6F9-D038
#
#  C:\Users\rtach 디렉터리
#
# 2025-06-22  오전 09:55    <DIR>          .
# 2025-06-22  오전 09:55    <DIR>          ..
# 2024-09-21  오후 11:40    <DIR>          .ammonite
# 2025-06-22  오전 08:29    <DIR>          .anaconda
# 2024-01-04  오전 11:56    <DIR>          .aws
# 2024-01-04  오전 11:56    <DIR>          .azure
# 2025-02-06  오전 12:28           226,770 .babel.json
# 2024-09-22  오후 04:31    <DIR>          .bloop
# 2024-09-21  오전 11:37    <DIR>          .bridge
# 2023-10-29  오전 10:32    <DIR>          .cache
# 2025-06-22  오전 09:57    <DIR>          .conda
# 2024-03-08  오전 12:01                25 .condarc
# 2024-09-22  오후 04:30    <DIR>          .config
# 2024-03-08  오전 12:01    <DIR>          .continuum
# 2025-02-18  오전 10:43    <DIR>          .docker
# 2024-09-22  오후 02:46             3,832 .dotty_history
# 2023-10-31  오후 01:26    <DIR>          .eclipse
# 2025-06-20  오후 11:24               178 .gitconfig
# ...

# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000002793E94E9B0>

# %%
# %matplotlib notebook
# %time
import os
import numpy as np
from matplotlib import pyplot as plt, font_manager, rcParams, matplotlib_fname
# rcParams['font.sans-serif'] = 'batang'
# rcParams['font.weight'] = 'regular'
# rcParams['axes.titlesize'] = 25

font_dir = font_manager.win32FontDirectory()
font_path = os.path.join(font_dir, 'batang.ttc')
font_prop = font_manager.FontProperties(fname=font_path)

x = np.arange(0, 10, 0.2)
y = np.sin(x)

fig = plt.figure()
ax = fig.add_subplot(111)

# ax.set_title('한국어 타이틀', fontproperties=font_prop)
ax.set_title('한국어 타이틀')
ax.plot(x, y)
plt.show()
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# <div id='eef951be-d187-4bff-a359-18e890a53af5'></div>
